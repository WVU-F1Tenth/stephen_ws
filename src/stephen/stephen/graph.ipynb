# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from heapq import heappush, heappop
from graph_utils import Graph
from PIL import Image

# %%
# plt.close('all')
# grid = np.zeros((10, 10))

# fig, ax = plt.subplots()
# im = ax.imshow(
#     grid, 
#     cmap='gray', 
#     origin='lower', 
#     interpolation='nearest',
#     vmin=0, vmax=1
# )
# ax.set_title("A* Search Visualization")

# def update(step):
#     if step == 0:
#         grid.fill(0)
#     grid[step, step] = 1
#     im.set_data(grid)
#     return [im]

# ani = FuncAnimation(fig, update, frames=10, interval=200, repeat=True, cache_frame_data=False)

# plt.show()

# %%
desired_width = 100
img = Image.open('../data/images/maze2.png').transpose(Image.FLIP_TOP_BOTTOM).convert('L')
w, h = img.size
c = desired_width / w
w, h = int(w*c), int(h*c)
img = np.array(img.resize((w, h), resample=Image.Resampling.BILINEAR))
img = img >= 210
plt.figure(figsize=(4, 4))
plt.imshow(img, cmap='gray', origin='lower')

# %%
Graph(img, (5, 99), (93, 1), 'a*').show()
